# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# 数据集来源: http://archive.ics.uci.edu/ml/datasets/Heart+Disease
# - 选择这个数据集的原因在于特征既有离散型和连续型两种类型

# %%
df = pd.read_csv("processed.cleveland.data",header=None,names=["age","sex","cp","trestbps","chol","fbs","restectg","thalach","exang","oldpeak","slope","ca","thal","num"])
df.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restectg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0       2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0       2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0       2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0       0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0       2.0    172.0    0.0      1.4
#
#    slope   ca thal  num
# 0    3.0  0.0  6.0    0
# 1    2.0  3.0  3.0    2
# 2    2.0  2.0  7.0    1
# 3    3.0  0.0  3.0    0
# 4    1.0  0.0  3.0    0

# %%
# numerical or categorical
for index in df:
    print(index,len(set(df[index])))
# Out:
# age 41
# sex 2
# cp 4
# trestbps 50
# chol 152
# fbs 2
# restectg 3
# thalach 91
# exang 2
# oldpeak 40
# slope 3
# ca 5
# thal 4
# num 5

# %%
# drop ? values
print(len(df))
index = ["?" not in row for row in df.values]
# convert to np.float
dataset = df.values[index].astype(np.float32)
print(len(dataset))
# split to X,y
X,y = dataset[:,:-1],dataset[:,-1]
y = y.astype(np.int64)
print(X.shape)
print(y.shape)
# Out:
# 303
# 297
# (297, 13)
# (297,)

# %%
kinds = ["categorical" if len(set(col))<6 else "numerical"for col in X.T]
print(len(kinds))
# Out:
# 13

# %%
from sklearn.model_selection import train_test_split
from collections import Counter
X_train,X_test,y_train,y_test = train_test_split(X,y)

# %%
def entropy(y):
    precs = np.array(list(Counter(y).values()))/len(y)
    ent = np.sum(-1 * precs * np.log2(precs))
    return ent

# %%
# 选择哪个特征进行分裂
def decide_feature(X,y,fas,kinds):
    # fas refers to feature_available;if one feature can be splitted,this feature_available is True,else False
    (n_samples,n_features) = X.shape
    ers = np.zeros(n_features)
    bestfvs = np.zeros(n_features)
    for fi in range(n_features):
        if not fas[fi]:
            continue
        
        if kinds[fi] == "categorical":
            I,H = entropy(y),0
            for fv,c in Counter(X[:,fi]).items():
                splity = y[X[:,fi] == fv]
                proc = c/n_samples
                I -= proc * entropy(splity)
                H += -proc * np.log2(proc)
            ers[fi] = I/H
        else:
            for fv in list(sorted(set(X[:,fi])))[:-1]:
                splity_less = y[X[:,fi] <= fv]
                proc_less = len(splity_less) / n_samples
                splity_more = y[X[:,fi] > fv]
                proc_more = len(splity_more) / n_samples
                I = -proc_less * entropy(splity_less) - proc_more * entropy(splity_more) + entropy(y)
                H = -1*proc_less * np.log2(proc_less) - proc_more * np.log2(proc_more)
                if I/H > ers[fi]:
                    ers[fi] = I/H
                    bestfvs[fi] = fv
    return ers,bestfvs

# %%
fas = np.array([True]*len(y_train))
decide_feature(X_train,y_train,fas,kinds)
# Out:
# (array([0.50948719, 0.08542973, 0.14974306, 0.33776014, 0.12186033,
#         0.03619019, 0.06108251, 0.33174944, 0.16628755, 0.35876418,
#         0.09582386, 0.15547841, 0.19957044]),
#  array([ 76.,   0.,   0., 192., 360.,   0.,   0.,  71.,   0.,   4.,   0.,
#           0.,   0.]))

# %%
def build_tree(X,y,fas,kinds):
    counts = dict(Counter(y))
    if len(counts) == 1 or (fas==False).all():
        result = max(counts,key=counts.get)
        return {"counts":counts,"result":result}
    ers,bestfvs = decide_feature(X,y,fas,kinds)
    next_ = {}
    bestfi = np.argmax(ers)
    if kinds[bestfi] == "categorical":
        fas[bestfi] = False
        for fv in set(X[:,bestfi]):
            index = (X[:,bestfi] == fv) 
            next_["{}{}".format("==",fv)] = build_tree(X[index],y[index],fas,kinds)
    else:
        bestfv = bestfvs[bestfi]
        index_less = X[:,bestfi] <= bestfv
        fas_less = fas.copy()
        if len(set(X[index_less][:,bestfi])) == 1:
            fas_less[bestfi] = False
        next_["{}{}".format("<=",bestfv)] = build_tree(X[index_less],y[index_less],fas_less,kinds)
        index_more = X[:,bestfi] > bestfv
        fas_more = fas.copy()
        if len(set(X[index_more][:,bestfi])) == 1:
            fas_more[bestfi] = False
        next_["{}{}".format(">",bestfv)] = build_tree(X[index_more],y[index_more],fas_more,kinds)
    return {"fi":bestfi,"counts":counts,"result":None,"next":next_}

# %%
fas = np.array([True]*X_train.shape[-1])
tree = build_tree(X_train,y_train,fas,kinds)
tree
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in double_scalars
# {'fi': 0,
#  'counts': {0: 120, 1: 40, 4: 9, 2: 27, 3: 26},
#  'result': None,
#  'next': {'<=76.0': {'fi': 9,
#    'counts': {0: 120, 1: 40, 4: 8, 2: 27, 3: 26},
#    'result': None,
#    'next': {'<=4.0': {'fi': 3,
#      'counts': {0: 120, 1: 40, 4: 7, 2: 27, 3: 24},
#      'result': None,
#      'next': {'<=192.0': {'fi': 9,
#        'counts': {0: 120, 1: 40, 4: 7, 2: 27, 3: 23},
#        'result': None,
#        'next': {'<=3.5999999046325684': {'fi': 7,
#          'counts': {0: 120, 1: 40, 4: 6, 2: 26, 3: 23},
#          'result': None,
#          'next': {'<=71.0': {'counts': {2: 1}, 'result': 2},
#           '>71.0': {'fi': 7,
#            'counts': {0: 120, 1: 40, 4: 6, 2: 25, 3: 23},
#            'result': None,
#            'next': {'<=95.0': {'counts': {3: 2}, 'result': 3},
#             '>95.0': {'fi': 3,
#              'counts': {0: 120, 1: 40, 4: 6, 2: 25, 3: 21},
#              'result': None,
#              'next': {'<=180.0': {'fi': 3,
#                'counts': {0: 120, 1: 39, 4: 6, 2: 25, 3: 21},
#                'result': None,
#                'next': {'<=174.0': {'fi': 3,
#                  'counts': {0: 120, 1: 39, 4: 6, 2: 24, 3: 19},
#                  'result': None,
#                  'next': {'<=172.0': {'fi': 9,
#                    'counts': {0: 120, 1: 38, 4: 6, 2: 24, 3: 19},
#                    'result': None,
#                    'next': {'<=3.5': {'fi': 12,
#                      'counts': {0: 120, 1: 37, 4: 5, 2: 23, 3: 18},
#                      'result': None,
#                      'next': {'==3.0': {'fi': 7,
#                        'counts': {0: 97, 1: 13, 2: 5, 3: 3},
#                        'result': None,
#                        'next': {'<=108.0': {'fi': 0,
#                          'counts': {2: 2, 3: 1, 0: 1},
#                          'result': None,
#                          'next': {'<=60.0': {'counts': {0: 1}, 'result': 0},
#                           '>60.0': {'fi': 2,
#                            'counts': {2: 2, 3: 1},
#                            'result': None,
#                            'next': {'==4.0': {'fi': 3,
#                              'counts': {2: 2, 3: 1},
#                              'result': None,
#                              'next': {'<=120.0': {'counts': {3: 1},
#                                'result': 3},
#                               '>120.0': {'counts': {2: 2}, 'result': 2}}}}}}},
#                         '>108.0': {'fi': 9,
#                          'counts': {0: 96, 1: 13, 3: 2, 2: 3},
#                          'result': None,
#                          'next': {'<=3.0': {'fi': 3,
#                            'counts': {0: 95, 1: 13, 2: 3, 3: 1},
#                            'result': None,
#                            'next': {'<=100.0': {'fi': 5,
#                              'counts': {0: 2, 3: 1},
#                              'result': None,
#                              'next': {'==0.0': {'fi': 10,
#                                'counts': {0: 2, 3: 1},
#                                'result': None,
#                                'next': {'==2.0': {'fi': 0,
#                                  'counts': {0: 2, 3: 1},
#                                  'result': None,
#                                  'next': {'<=58.0': {'counts': {0: 2},
#                                    'result': 0},
#                                   '>58.0': {'counts': {3: 1},
#                                    'result': 3}}}}}}},
#                             '>100.0': {'fi': 9,
#                              'counts': {0: 93, 1: 13, 2: 3},
#                              'result': None,
#                              'next': {'<=2.4000000953674316': {'fi': 4,
#                                'counts': {0: 91, 1: 12, 2: 2},
#                                'result': None,
#                                'next': {'<=149.0': {'fi': 2,
#                                  'counts': {1: 1, 0: 1},
#                                  'result': None,
#                                  'next': {'==3.0': {'fi': 5,
#                                    'counts': {1: 1, 0: 1},
#                                    'result': None,
#                                    'next': {'==0.0': {'fi': 8,
#                                      'counts': {1: 1, 0: 1},
#                                      'result': None,
#                                      'next': {'==0.0': {'fi': 0,
#                                        'counts': {1: 1, 0: 1},
#                                        'result': None,
#                                        'next': {'<=44.0': {'counts': {0: 1},
#                                          'result': 0},
#                                         '>44.0': {'counts': {1: 1},
#                                          'result': 1}}}}}}}}},
#                                 '>149.0': {'fi': 3,
#                                  'counts': {0: 90, 1: 11, 2: 2},
#                                  'result': None,
#                                  'next': {'<=112.0': {'fi': 7,
#                                    'counts': {0: 12, 2: 2, 1: 3},
#                                    'result': None,
#                                    'next': {'<=172.0': {'fi': 3,
#                                      'counts': {0: 12, 2: 2, 1: 2},
#                                      'result': None,
#                                      'next': {'<=110.0': {'fi': 1,
#                                        'counts': {0: 10, 1: 1},
#                                        'result': None,
#                                        'next': {'==0.0': {'counts': {0: 7},
#                                          'result': 0},
#                                         '==1.0': {'fi': 5,
#                                          'counts': {0: 3, 1: 1},
#                                          'result': None,
#                                          'next': {'==0.0': {'fi': 11,
#                                            'counts': {0: 3, 1: 1},
#                                            'result': None,
#                                            'next': {'==0.0': {'fi': 3,
#                                              'counts': {0: 3, 1: 1},
#                                              'result': None,
#                                              'next': {'<=108.0': {'counts': {1: 1},
#                                                'result': 1},
#                                               '>108.0': {'counts': {0: 3},
#                                                'result': 0}}}}}}}}},
#                                       '>110.0': {'fi': 5,
#                                        'counts': {2: 2, 1: 1, 0: 2},
#                                        'result': None,
#                                        'next': {'==0.0': {'fi': 4,
#                                          'counts': {2: 2, 1: 1, 0: 2},
#                                          'result': None,
#                                          'next': {'<=204.0': {'counts': {0: 2},
#                                            'result': 0},
#                                           '>204.0': {'fi': 1,
#                                            'counts': {2: 2, 1: 1},
#                                            'result': None,
#                                            'next': {'==1.0': {'fi': 2,
#                                              'counts': {2: 2, 1: 1},
#                                              'result': None,
#                                              'next': {'==4.0': {'fi': 10,
#                                                'counts': {2: 2, 1: 1},
#                                                'result': None,
#                                                'next': {'==1.0': {'fi': 11,
#                                                  'counts': {2: 2, 1: 1},
#                                                  'result': None,
#                                                  'next': {'==1.0': {'fi': 6,
#                                                    'counts': {2: 2, 1: 1},
#                                                    'result': None,
#                                                    'next': {'==0.0': {'counts': {1: 1},
#                                                      'result': 1},
#                                                     '==2.0': {'counts': {2: 2},
#                                                      'result': 2}}}}}}}}}}}}}}}}},
#                                     '>172.0': {'counts': {1: 1},
#                                      'result': 1}}},
#                                   '>112.0': {'fi': 0,
#                                    'counts': {0: 78, 1: 8},
#                                    'result': None,
#                                    'next': {'<=57.0': {'counts': {0: 56},
#                                      'result': 0},
#                                     '>57.0': {'fi': 0,
#                                      'counts': {1: 8, 0: 22},
#                                      'result': None,
#                                      'next': {'<=65.0': {'fi': 8,
#                                        'counts': {1: 8, 0: 13},
#                                        'result': None,
#                                        'next': {'==0.0': {'fi': 4,
#                                          'counts': {1: 6, 0: 13},
#                                          'result': None,
#                                          'next': {'<=330.0': {'fi': 3,
#                                            'counts': {1: 6, 0: 10},
#                                            'result': None,
#                                            'next': {'<=150.0': {'fi': 0,
#                                              'counts': {1: 4, 0: 10},
#                                              'result': None,
#                                              'next': {'<=64.0': {'fi': 3,
#                                                'counts': {1: 3, 0: 10},
#                                                'result': None,
#                                                'next': {'<=120.0': {'counts': {1: 1},
#                                                  'result': 1},
#                                                 '>120.0': {'fi': 4,
#                                                  'counts': {1: 2, 0: 10},
#                                                  'result': None,
#                                                  'next': {'<=303.0': {'fi': 4,
#                                                    'counts': {0: 10, 1: 1},
#                                                    'result': None,
#                                                    'next': {'<=204.0': {'fi': 5,
#                                                      'counts': {0: 2, 1: 1},
#                                                      'result': None,
#                                                      'next': {'==0.0': {'fi': 6,
#                                                        'counts': {0: 2, 1: 1},
#                                                        'result': None,
#                                                        'next': {'==0.0': {'fi': 1,
#                                                          'counts': {0: 2,
#                                                           1: 1},
#                                                          'result': None,
#                                                          'next': {'==0.0': {'counts': {0: 2},
#                                                            'result': 0},
#                                                           '==1.0': {'counts': {1: 1},
#                                                            'result': 1}}}}}}},
#                                                     '>204.0': {'counts': {0: 8},
#                                                      'result': 0}}},
#                                                   '>303.0': {'counts': {1: 1},
#                                                    'result': 1}}}}},
#                                               '>64.0': {'counts': {1: 1},
#                                                'result': 1}}},
#                                             '>150.0': {'counts': {1: 2},
#                                              'result': 1}}},
#                                           '>330.0': {'counts': {0: 3},
#                                            'result': 0}}},
#                                         '==1.0': {'counts': {1: 2},
#                                          'result': 1}}},
#                                       '>65.0': {'counts': {0: 9},
#                                        'result': 0}}}}}}}}},
#                               '>2.4000000953674316': {'fi': 5,
#                                'counts': {1: 1, 0: 2, 2: 1},
#                                'result': None,
#                                'next': {'==0.0': {'fi': 4,
#                                  'counts': {1: 1, 0: 2, 2: 1},
#                                  'result': None,
#                                  'next': {'<=185.0': {'counts': {1: 1},
#                                    'result': 1},
#                                   '>185.0': {'fi': 4,
#                                    'counts': {0: 2, 2: 1},
#                                    'result': None,
#                                    'next': {'<=226.0': {'counts': {0: 2},
#                                      'result': 0},
#                                     '>226.0': {'counts': {2: 1},
#                                      'result': 2}}}}}}}}}}},
#                           '>3.0': {'fi': 1,
#                            'counts': {3: 1, 0: 1},
#                            'result': None,
#                            'next': {'==1.0': {'fi': 5,
#                              'counts': {3: 1, 0: 1},
#                              'result': None,
#                              'next': {'==0.0': {'fi': 0,
#                                'counts': {3: 1, 0: 1},
#                                'result': None,
#                                'next': {'<=37.0': {'counts': {0: 1},
#                                  'result': 0},
#                                 '>37.0': {'counts': {3: 1},
#                                  'result': 3}}}}}}}}}}},
#                       '==6.0': {'fi': 1,
#                        'counts': {4: 1, 1: 2, 2: 4, 0: 4},
#                        'result': None,
#                        'next': {'==1.0': {'fi': 6,
#                          'counts': {4: 1, 1: 2, 2: 4, 0: 4},
#                          'result': None,
#                          'next': {'==0.0': {'fi': 0,
#                            'counts': {2: 4, 0: 2},
#                            'result': None,
#                            'next': {'<=41.0': {'counts': {0: 1}, 'result': 0},
#                             '>41.0': {'fi': 3,
#                              'counts': {2: 4, 0: 1},
#                              'result': None,
#                              'next': {'<=110.0': {'counts': {0: 1},
#                                'result': 0},
#                               '>110.0': {'counts': {2: 4}, 'result': 2}}}}},
#                           '==2.0': {'fi': 5,
#                            'counts': {4: 1, 1: 2, 0: 2},
#                            'result': None,
#                            'next': {'==0.0': {'fi': 11,
#                              'counts': {4: 1, 1: 2, 0: 2},
#                              'result': None,
#                              'next': {'==0.0': {'counts': {0: 2}, 'result': 0},
#                               '==1.0': {'counts': {1: 1}, 'result': 1},
#                               '==2.0': {'fi': 2,
#                                'counts': {4: 1, 1: 1},
#                                'result': None,
#                                'next': {'==4.0': {'fi': 8,
#                                  'counts': {4: 1, 1: 1},
#                                  'result': None,
#                                  'next': {'==0.0': {'fi': 0,
#                                    'counts': {4: 1, 1: 1},
#                                    'result': None,
#                                    'next': {'<=64.0': {'counts': {4: 1},
#                                      'result': 4},
#                                     '>64.0': {'counts': {1: 1},
#                                      'result': 1}}}}}}}}}}}}}}},
#                       '==7.0': {'fi': 0,
#                        'counts': {0: 19, 1: 22, 3: 15, 2: 14, 4: 4},
#                        'result': None,
#                        'next': {'<=69.0': {'fi': 3,
#                          'counts': {0: 19, 1: 22, 3: 14, 2: 14, 4: 3},
#                          'result': None,
#                          'next': {'<=152.0': {'fi': 0,
#                            'counts': {0: 18, 1: 21, 3: 14, 2: 14, 4: 1},
#                            'result': None,
#                            'next': {'<=68.0': {'fi': 7,
#                              'counts': {0: 18, 1: 21, 3: 14, 2: 13, 4: 1},
#                              'result': None,
#                              'next': {'<=97.0': {'counts': {2: 1},
#                                'result': 2},
#                               '>97.0': {'fi': 3,
#                                'counts': {0: 18, 1: 21, 3: 14, 2: 12, 4: 1},
#                                'result': None,
#                                'next': {'<=108.0': {'fi': 0,
#                                  'counts': {2: 1, 0: 4},
#                                  'result': None,
#                                  'next': {'<=54.0': {'counts': {0: 3},
#                                    'result': 0},
#                                   '>54.0': {'fi': 3,
#                                    'counts': {2: 1, 0: 1},
#                                    'result': None,
#                                    'next': {'<=100.0': {'counts': {2: 1},
#                                      'result': 2},
#                                     '>100.0': {'counts': {0: 1},
#                                      'result': 0}}}}},
#                                 '>108.0': {'fi': 0,
#                                  'counts': {0: 14, 1: 21, 3: 14, 4: 1, 2: 11},
#                                  'result': None,
#                                  'next': {'<=67.0': {'fi': 4,
#                                    'counts': {0: 13,
#                                     1: 21,
#                                     3: 14,
#                                     4: 1,
#                                     2: 11},
#                                    'result': None,
#                                    'next': {'<=126.0': {'counts': {0: 1},
#                                      'result': 0},
#                                     '>126.0': {'fi': 4,
#                                      'counts': {0: 12,
#                                       1: 21,
#                                       3: 14,
#                                       4: 1,
#                                       2: 11},
#                                      'result': None,
#                                      'next': {'<=409.0': {'fi': 4,
#                                        'counts': {1: 21,
#                                         3: 14,
#                                         0: 11,
#                                         4: 1,
#                                         2: 11},
#                                        'result': None,
#                                        'next': {'<=330.0': {'fi': 0,
#                                          'counts': {1: 21,
#                                           3: 14,
#                                           0: 11,
#                                           4: 1,
#                                           2: 9},
#                                          'result': None,
#                                          'next': {'<=65.0': {'fi': 4,
#                                            'counts': {1: 21,
#                                             3: 13,
#                                             0: 11,
#                                             4: 1,
#                                             2: 9},
#                                            'result': None,
#                                            'next': {'<=167.0': {'counts': {3: 1},
#                                              'result': 3},
#                                             '>167.0': {'fi': 4,
#                                              'counts': {1: 21,
#                                               3: 12,
#                                               0: 11,
#                                               4: 1,
#                                               2: 9},
#                                              'result': None,
#                                              'next': {'<=313.0': {'fi': 4,
#                                                'counts': {1: 21,
#                                                 3: 11,
#                                                 0: 11,
#                                                 4: 1,
#                                                 2: 9},
#                                                'result': None,
#                                                'next': {'<=311.0': {'fi': 4,
#                                                  'counts': {1: 21,
#                                                   3: 11,
#                                                   0: 10,
#                                                   4: 1,
#                                                   2: 9},
#                                                  'result': None,
#                                                  'next': {'<=309.0': {'fi': 0,
#                                                    'counts': {1: 21,
#                                                     3: 11,
#                                                     0: 10,
#                                                     4: 1,
#                                                     2: 8},
#                                                    'result': None,
#                                                    'next': {'<=64.0': {'fi': 7,
#                                                      'counts': {1: 21,
#                                                       3: 11,
#                                                       0: 9,
#                                                       4: 1,
#                                                       2: 7},
#                                                      'result': None,
#                                                      'next': {'<=171.0': {'fi': 7,
#                                                        'counts': {1: 19,
#                                                         3: 11,
#                                                         0: 6,
#                                                         4: 1,
#                                                         2: 7},
#                                                        'result': None,
#                                                        'next': {'<=163.0': {'fi': 3,
#                                                          'counts': {1: 18,
#                                                           3: 10,
#                                                           0: 6,
#                                                           2: 7},
#                                                          'result': None,
#                                                          'next': {'<=148.0': {'fi': 3,
#                                                            'counts': {1: 18,
#                                                             3: 9,
#                                                             0: 6,
#                                                             2: 7},
#                                                            'result': None,
#                                                            'next': {'<=146.0': {'fi': 7,
#                                                              'counts': {1: 18,
#                                                               3: 9,
#                                                               0: 6,
#                                                               2: 6},
#                                                              'result': None,
#                                                              'next': {'<=158.0': {'fi': 4,
#                                                                'counts': {1: 16,
#                                                                 3: 9,
#                                                                 0: 3,
#                                                                 2: 4},
#                                                                'result': None,
#                                                                'next': {'<=281.0': {'fi': 0,
#                                                                  'counts': {1: 14,
#                                                                   3: 8,
#                                                                   0: 3,
#                                                                   2: 1},
#                                                                  'result': None,
#                                                                  'next': {'<=62.0': {'fi': 4,
#                                                                    'counts': {1: 14,
#                                                                     3: 8,
#                                                                     0: 2,
#                                                                     2: 1},
#                                                                    'result': None,
#                                                                    'next': {'<=200.0': {'fi': 0,
#                                                                      'counts': {3: 3,
#                                                                       1: 1,
#                                                                       2: 1},
#                                                                      'result': None,
#                                                                      'next': {'<=41.0': {'counts': {1: 1},
#                                                                        'result': 1},
#                                                                       '>41.0': {'fi': 10,
#                                                                        'counts': {3: 3,
#                                                                         2: 1},
#                                                                        'result': None,
#                                                                        'next': {'==2.0': {'fi': 0,
#                                                                          'counts': {3: 3,
#                                                                           2: 1},
#                                                                          'result': None,
#                                                                          'next': {'<=50.0': {'counts': {3: 3},
#                                                                            'result': 3},
#                                                                           '>50.0': {'counts': {2: 1},
#                                                                            'result': 2}}}}}}},
#                                                                     '>200.0': {'fi': 9,
#                                                                      'counts': {1: 13,
#                                                                       0: 2,
#                                                                       3: 5},
#                                                                      'result': None,
#                                                                      'next': {'<=0.0': {'fi': 10,
#                                                                        'counts': {0: 1,
#                                                                         3: 1},
#                                                                        'result': None,
#                                                                        'next': {'==1.0': {'fi': 0,
#                                                                          'counts': {0: 1,
#                                                                           3: 1},
#                                                                          'result': None,
#                                                                          'next': {'<=48.0': {'counts': {3: 1},
#                                                                            'result': 3},
#                                                                           '>48.0': {'counts': {0: 1},
#                                                                            'result': 0}}}}},
#                                                                       '>0.0': {'fi': 4,
#                                                                        'counts': {1: 13,
#                                                                         0: 1,
#                                                                         3: 4},
#                                                                        'result': None,
#                                                                        'next': {'<=267.0': {'fi': 0,
#                                                                          'counts': {1: 13,
#                                                                           0: 1,
#                                                                           3: 3},
#                                                                          'result': None,
#                                                                          'next': {'<=61.0': {'fi': 7,
#                                                                            'counts': {1: 12,
#                                                                             3: 3},
#                                                                            'result': None,
#                                                                            'next': {'<=130.0': {'fi': 10,
#                                                                              'counts': {1: 3,
#                                                                               3: 3},
#                                                                              'result': None,
#                                                                              'next': {'==2.0': {'fi': 7,
#                                                                                'counts': {1: 3,
#                                                                                 3: 3},
#                                                                                'result': None,
#                                                                                'next': {'<=123.0': {'counts': {1: 3},
#                                                                                  'result': 1},
#                                                                                 '>123.0': {'counts': {3: 3},
#                                                                                  'result': 3}}}}},
#                                                                             '>130.0': {'counts': {1: 9},
#                                                                              'result': 1}}},
#                                                                           '>61.0': {'fi': 10,
#                                                                            'counts': {0: 1,
#                                                                             1: 1},
#                                                                            'result': None,
#                                                                            'next': {'==2.0': {'fi': 3,
#                                                                              'counts': {0: 1,
#                                                                               1: 1},
#                                                                              'result': None,
#                                                                              'next': {'<=120.0': {'counts': {1: 1},
#                                                                                'result': 1},
#                                                                               '>120.0': {'counts': {0: 1},
#                                                                                'result': 0}}}}}}},
#                                                                         '>267.0': {'counts': {3: 1},
#                                                                          'result': 3}}}}}}},
#                                                                   '>62.0': {'counts': {0: 1},
#                                                                    'result': 0}}},
#                                                                 '>281.0': {'fi': 0,
#                                                                  'counts': {2: 3,
#                                                                   3: 1,
#                                                                   1: 2},
#                                                                  'result': None,
#                                                                  'next': {'<=45.0': {'counts': {3: 1},
#                                                                    'result': 3},
#                                                                   '>45.0': {'fi': 0,
#                                                                    'counts': {2: 3,
#                                                                     1: 2},
#                                                                    'result': None,
#                                                                    'next': {'<=60.0': {'counts': {2: 3},
#                                                                      'result': 2},
#                                                                     '>60.0': {'counts': {1: 2},
#                                                                      'result': 1}}}}}}},
#                                                               '>158.0': {'fi': 0,
#                                                                'counts': {0: 3,
#                                                                 2: 2,
#                                                                 1: 2},
#                                                                'result': None,
#                                                                'next': {'<=52.0': {'fi': 0,
#                                                                  'counts': {1: 2,
#                                                                   0: 1},
#                                                                  'result': None,
#                                                                  'next': {'<=43.0': {'counts': {0: 1},
#                                                                    'result': 0},
#                                                                   '>43.0': {'counts': {1: 2},
#                                                                    'result': 1}}},
#                                                                 '>52.0': {'fi': 10,
#                                                                  'counts': {0: 2,
#                                                                   2: 2},
#                                                                  'result': None,
#                                                                  'next': {'==1.0': {'counts': {2: 2},
#                                                                    'result': 2},
#                                                                   '==2.0': {'counts': {0: 2},
#                                                                    'result': 0}}}}}}},
#                                                             '>146.0': {'counts': {2: 1},
#                                                              'result': 2}}},
#                                                           '>148.0': {'counts': {3: 1},
#                                                            'result': 3}}},
#                                                         '>163.0': {'fi': 0,
#                                                          'counts': {4: 1,
#                                                           1: 1,
#                                                           3: 1},
#                                                          'result': None,
#                                                          'next': {'<=52.0': {'counts': {3: 1},
#                                                            'result': 3},
#                                                           '>52.0': {'fi': 3,
#                                                            'counts': {4: 1,
#                                                             1: 1},
#                                                            'result': None,
#                                                            'next': {'<=112.0': {'counts': {4: 1},
#                                                              'result': 4},
#                                                             '>112.0': {'counts': {1: 1},
#                                                              'result': 1}}}}}}},
#                                                       '>171.0': {'fi': 4,
#                                                        'counts': {0: 3, 1: 2},
#                                                        'result': None,
#                                                        'next': {'<=298.0': {'fi': 7,
#                                                          'counts': {0: 3,
#                                                           1: 1},
#                                                          'result': None,
#                                                          'next': {'<=178.0': {'counts': {0: 3},
#                                                            'result': 0},
#                                                           '>178.0': {'counts': {1: 1},
#                                                            'result': 1}}},
#                                                         '>298.0': {'counts': {1: 1},
#                                                          'result': 1}}}}},
#                                                     '>64.0': {'fi': 3,
#                                                      'counts': {0: 1, 2: 1},
#                                                      'result': None,
#                                                      'next': {'<=120.0': {'counts': {0: 1},
#                                                        'result': 0},
#                                                       '>120.0': {'counts': {2: 1},
#                                                        'result': 2}}}}},
#                                                   '>309.0': {'counts': {2: 1},
#                                                    'result': 2}}},
#                                                 '>311.0': {'counts': {0: 1},
#                                                  'result': 0}}},
#                                               '>313.0': {'counts': {3: 1},
#                                                'result': 3}}}}},
#                                           '>65.0': {'counts': {3: 1},
#                                            'result': 3}}},
#                                         '>330.0': {'counts': {2: 2},
#                                          'result': 2}}},
#                                       '>409.0': {'counts': {0: 1},
#                                        'result': 0}}}}},
#                                   '>67.0': {'counts': {0: 1},
#                                    'result': 0}}}}}}},
#                             '>68.0': {'counts': {2: 1}, 'result': 2}}},
#                           '>152.0': {'fi': 0,
#                            'counts': {1: 1, 4: 2, 0: 1},
#                            'result': None,
#                            'next': {'<=52.0': {'counts': {0: 1}, 'result': 0},
#                             '>52.0': {'fi': 10,
#                              'counts': {1: 1, 4: 2},
#                              'result': None,
#                              'next': {'==2.0': {'fi': 0,
#                                'counts': {1: 1, 4: 2},
#                                'result': None,
#                                'next': {'<=57.0': {'counts': {4: 2},
#                                  'result': 4},
#                                 '>57.0': {'counts': {1: 1},
#                                  'result': 1}}}}}}}}},
#                         '>69.0': {'fi': 3,
#                          'counts': {3: 1, 4: 1},
#                          'result': None,
#                          'next': {'<=145.0': {'counts': {4: 1}, 'result': 4},
#                           '>145.0': {'counts': {3: 1}, 'result': 3}}}}}}},
#                     '>3.5': {'fi': 5,
#                      'counts': {4: 1, 3: 1, 1: 1, 2: 1},
#                      'result': None,
#                      'next': {'==0.0': {'fi': 0,
#                        'counts': {4: 1, 3: 1, 1: 1, 2: 1},
#                        'result': None,
#                        'next': {'<=46.0': {'counts': {1: 1}, 'result': 1},
#                         '>46.0': {'fi': 2,
#                          'counts': {4: 1, 3: 1, 2: 1},
#                          'result': None,
#                          'next': {'==4.0': {'fi': 0,
#                            'counts': {4: 1, 3: 1, 2: 1},
#                            'result': None,
#                            'next': {'<=61.0': {'fi': 1,
#                              'counts': {4: 1, 2: 1},
#                              'result': None,
#                              'next': {'==1.0': {'fi': 8,
#                                'counts': {4: 1, 2: 1},
#                                'result': None,
#                                'next': {'==1.0': {'fi': 10,
#                                  'counts': {4: 1, 2: 1},
#                                  'result': None,
#                                  'next': {'==2.0': {'fi': 11,
#                                    'counts': {4: 1, 2: 1},
#                                    'result': None,
#                                    'next': {'==1.0': {'fi': 3,
#                                      'counts': {4: 1, 2: 1},
#                                      'result': None,
#                                      'next': {'<=120.0': {'counts': {2: 1},
#                                        'result': 2},
#                                       '>120.0': {'counts': {4: 1},
#                                        'result': 4}}}}}}}}}}},
#                             '>61.0': {'counts': {3: 1}, 'result': 3}}}}}}}}}}},
#                   '>172.0': {'counts': {1: 1}, 'result': 1}}},
#                 '>174.0': {'fi': 8,
#                  'counts': {3: 2, 2: 1},
#                  'result': None,
#                  'next': {'==1.0': {'fi': 10,
#                    'counts': {3: 2, 2: 1},
#                    'result': None,
#                    'next': {'==2.0': {'fi': 0,
#                      'counts': {3: 2, 2: 1},
#                      'result': None,
#                      'next': {'<=55.0': {'counts': {2: 1}, 'result': 2},
#                       '>55.0': {'counts': {3: 2}, 'result': 3}}}}}}}}},
#               '>180.0': {'counts': {1: 1}, 'result': 1}}}}}}},
#         '>3.5999999046325684': {'fi': 2,
#          'counts': {2: 1, 4: 1},
#          'result': None,
#          'next': {'==4.0': {'fi': 5,
#            'counts': {2: 1, 4: 1},
#            'result': None,
#            'next': {'==0.0': {'fi': 6,
#              'counts': {2: 1, 4: 1},
#              'result': None,
#              'next': {'==2.0': {'fi': 12,
#                'counts': {2: 1, 4: 1},
#                'result': None,
#                'next': {'==7.0': {'fi': 1,
#                  'counts': {2: 1, 4: 1},
#                  'result': None,
#                  'next': {'==0.0': {'counts': {4: 1}, 'result': 4},
#                   '==1.0': {'counts': {2: 1}, 'result': 2}}}}}}}}}}}}},
#       '>192.0': {'counts': {3: 1}, 'result': 3}}},
#     '>4.0': {'fi': 2,
#      'counts': {3: 2, 4: 1},
#      'result': None,
#      'next': {'==4.0': {'fi': 5,
#        'counts': {3: 2, 4: 1},
#        'result': None,
#        'next': {'==0.0': {'fi': 11,
#          'counts': {3: 2, 4: 1},
#          'result': None,
#          'next': {'==3.0': {'fi': 3,
#            'counts': {3: 2, 4: 1},
#            'result': None,
#            'next': {'<=114.0': {'counts': {4: 1}, 'result': 4},
#             '>114.0': {'counts': {3: 2}, 'result': 3}}}}}}}}}}},
#   '>76.0': {'counts': {4: 1}, 'result': 4}}}

# %%
# build_tree 里面有两个错误，一是在计算信息增益率时除数不能为0，二是终止条件需要改进

# %%
def predict_one(x,kinds,tree):
    while tree["result"] == None:
        fi = tree["fi"]
        fv = x[fi]
        flag = False
        for condition in tree["next"]:
            if eval(str(fv)+condition):
                tree = tree["next"][condition]
                flag = True
                break
        if not flag:
            counts = tree["counts"]
            return max(counts,key=counts.get)
    return tree["result"]

# %%
class C45DecisionTree:
    @staticmethod
    def entropy(y):
        precs = np.array(list(Counter(y).values()))/len(y)
        ent = np.sum(-1 * precs * np.log2(precs))
        return ent

    # 选择哪个特征进行分裂
    def decide_feature(self,X,y,fas,kinds):
        # fas refers to feature_available;if one feature can be splitted,this feature_available is True,else False
        (n_samples,n_features) = X.shape
        ers = np.ones(n_features) * -1
        bestfvs = np.zeros(n_features)
        for fi in range(n_features):
            if not fas[fi]:
                continue

            if kinds[fi] == "categorical":
                I,H = self.entropy(y),0
                for fv,c in Counter(X[:,fi]).items():
                    splity = y[X[:,fi] == fv]
                    proc = c/n_samples
                    I -= proc * self.entropy(splity)
                    H += -proc * np.log2(proc)
                ers[fi] = I/(H+1e-7)
            else:
#                 print(set(X[:,fi]))
                for fv in list(sorted(set(X[:,fi])))[:-1]:
                    splity_less = y[X[:,fi] <= fv]
                    proc_less = len(splity_less) / n_samples
                    splity_more = y[X[:,fi] > fv]
                    proc_more = len(splity_more) / n_samples
                    I = -proc_less * self.entropy(splity_less) - proc_more * self.entropy(splity_more) + self.entropy(y)
                    H = -1*proc_less * np.log2(proc_less) - proc_more * np.log2(proc_more)
                    if I/(H+1e-7) > ers[fi]:
                        ers[fi] = I/(H+1e-7)
                        bestfvs[fi] = fv
        return ers,bestfvs

    def build_tree(self,X,y,fas,kinds):
        counts = dict(Counter(y))
        result = max(counts,key=counts.get)
#         print("fas",fas,"len(counts)",len(counts))
        if len(counts) == 1 or (fas==False).all():
            return {"counts":counts,"result":result}
        ers,bestfvs = self.decide_feature(X,y,fas,kinds)
        if (ers == -1).all():
            return {"counts":counts,"result":result}
        next_ = {}
        bestfi = np.argmax(ers)
#         print(bestfi,ers)
        if kinds[bestfi] == "categorical":
            fas[bestfi] = False
            for fv in set(X[:,bestfi]):
                index = (X[:,bestfi] == fv)
#                 print("next: {} {} {}, size:{}".format(bestfi,"==",fv,len(y[index])))
                next_["{}{}".format("==",fv)] = self.build_tree(X[index],y[index],fas,kinds)
        else:
            bestfv = bestfvs[bestfi]
            index_less = X[:,bestfi] <= bestfv
            fas_less = fas.copy()
            if len(set(X[index_less][:,bestfi])) == 1:
                fas_less[bestfi] = False
#             print("next: {} {} {}, size:{}".format(bestfi,"<=",bestfv,len(y[index_less])))
            next_["{}{}".format("<=",bestfv)] = self.build_tree(X[index_less],y[index_less],fas_less,kinds)
            index_more = X[:,bestfi] > bestfv
            fas_more = fas.copy()
            if len(set(X[index_more][:,bestfi])) == 1:
                fas_more[bestfi] = False
#             print("next: {} {} {}, size:{}".format(bestfi,">=",bestfv,len(y[index_more])))
            next_["{}{}".format(">",bestfv)] = self.build_tree(X[index_more],y[index_more],fas_more,kinds)
        return {"fi":bestfi,"counts":counts,"result":None,"next":next_}
    
    def fit(self,X,y,kinds):
        fas = np.array([True]*X.shape[-1])
        self.tree = self.build_tree(X,y,fas,kinds)

    def predict_one(self,x):
        tree = self.tree
        while tree["result"] == None:
            fi = tree["fi"]
            fv = x[fi]
            flag = False
            for condition in tree["next"]:
                if eval(str(fv)+condition):
                    tree = tree["next"][condition]
                    flag = True
                    break
            if not flag:
                counts = tree["counts"]
                return max(counts,key=counts.get)
        return tree["result"]
    
    def predict(self,X):
        y_predicts = []
        for x_test in X_test:
            y_predicts.append(self.predict_one(x_test))
        return y_predicts
        
    def score(self,X_test,y_test):
        y_predicts = self.predict(X_test)
        return np.sum(y_predicts == y_test)/ len(y_test)

# %%
mytree = C45DecisionTree()
mytree.fit(X_train,y_train,kinds)
mytree.score(X_test,y_test)
# Out:
# 0.44
